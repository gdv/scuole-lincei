# %% [markdown]
# # Introduzione a Python per la Data Science
#
# # Inizio ore 14.30
#
# ## Lavagna condivisa [https://board.net/p/lincei](https://board.net/p/lincei)
#
#
# 1.  elenco numerato
# 2.  seconda voce
# 1.  terza **voce**
# 1.  $\sum_{i=1}^99 4^{i}$

# %%
a = 4
a
# Out:
# 4

# %%
type(a)
# Out:
# int

# %%
a = 'pippo'
type(a)
# Out:
# str

# %%
1 +2 *9
# Out:
# 19

# %%
lista = [1, 99, 'testo lungo', 8.14]
lista
# Out:
# [1, 99, 'testo lungo', 8.14]

# %%
lista[1]
# Out:
# 99

# %%
lista[0]
# Out:
# 1

# %%
lista[-1]
# Out:
# 8.14

# %%
lista[1:3]
# Out:
# [99, 'testo lungo']

# %%
lista.append(6)
lista
# Out:
# [1, 99, 'testo lungo', 8.14, 6]

# %%
lista[1:5:2]
# Out:
# [99, 8.14]

# %%
lista[::-1]
# Out:
# [6, 8.14, 'testo lungo', 99, 1]

# %%
lista[:3]
# Out:
# [1, 99, 'testo lungo']

# %%
dizionario = {'Rossi': 12, 'Bianchi': 27}
dizionario
# Out:
# {'Rossi': 12, 'Bianchi': 27}

# %%
dizionario = {'Rossi': 12, 'Bianchi': 27, 99: 'valore'}
dizionario
# Out:
# {'Rossi': 12, 'Bianchi': 27, 99: 'valore'}

# %%
testo = 'asdijwneviahurhetrhnvasdopvuweugndfsdvierionvsdunsdvr'

# %% [markdown]
# ## Esercizio
#
# Per ogni lettera, calcolare quante volte compare in `testo`

# %%
testo[5]
# Out:
# 'w'

# %%
import collections

# %%
contatore = collections.Counter(testo)
contatore
# Out:
# Counter({'a': 3,
#          's': 5,
#          'd': 6,
#          'i': 4,
#          'j': 1,
#          'w': 2,
#          'n': 5,
#          'e': 4,
#          'v': 6,
#          'h': 3,
#          'u': 4,
#          'r': 4,
#          't': 1,
#          'o': 2,
#          'p': 1,
#          'g': 1,
#          'f': 1})

# %%
contatore.most_common(3)
# Out:
# [('d', 6), ('v', 6), ('s', 5)]

# %%
conta = {}

# %%
for carattere in testo:
    if carattere in conta:
        conta[carattere] += 1
    else:
        conta[carattere] = 1
conta
# Out:
# {'a': 3,
#  's': 5,
#  'd': 6,
#  'i': 4,
#  'j': 1,
#  'w': 2,
#  'n': 5,
#  'e': 4,
#  'v': 6,
#  'h': 3,
#  'u': 4,
#  'r': 4,
#  't': 1,
#  'o': 2,
#  'p': 1,
#  'g': 1,
#  'f': 1}

# %%
for (unsigned int i=0; i<len(testo); i++) {
if testo[i] in conta
conta[testo[i]] += 1;
else
conta[testo[i]] = 1;
}
printf("%s\n", conta);

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
pd.read_csv("https://github.com/gdv/scuole-lincei/raw/master/data/googleplaystore.csv")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## DataFrame
#
# Una tabella molto simile a quella di SQL.

# %%
play = pd.read_csv("https://github.com/gdv/scuole-lincei/raw/master/data/googleplaystore.csv")
play
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
type(play)
# Out:
# pandas.core.frame.DataFrame

# %%
play.iloc[100]
# Out:
# App               Natural recipes for your beauty
# Category                                   BEAUTY
# Rating                                        4.7
# Reviews                                      1150
# Size                                         9.8M
# Installs                                 100,000+
# Type                                         Free
# Price                                           0
# Content Rating                           Everyone
# Genres                                     Beauty
# Last Updated                         May 15, 2018
# Current Ver                                   4.0
# Android Ver                            4.1 and up
# Name: 100, dtype: object

# %%
play.iloc[100:102]
# Out:
#                                                    App Category  Rating  \
# 100                    Natural recipes for your beauty   BEAUTY     4.7
# 101  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
#
#     Reviews  Size  Installs  Type Price Content Rating  Genres   Last Updated  \
# 100    1150  9.8M  100,000+  Free     0       Everyone  Beauty   May 15, 2018
# 101    1739   21M  500,000+  Free     0       Everyone  Beauty  July 12, 2018
#
#     Current Ver   Android Ver
# 100         4.0    4.1 and up
# 101       1.0.6  4.0.3 and up

# %%
play['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
type(play['App'])
# Out:
# pandas.core.series.Series

# %%
play['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
play['Rating'].mean()
# Out:
# 4.193338315362443

# %%
list(play['Rating'])
# Out:
# [4.1,
#  3.9,
#  4.7,
#  4.5,
#  4.3,
#  4.4,
#  3.8,
#  4.1,
#  4.4,
#  4.7,
#  4.4,
#  4.4,
#  4.2,
#  4.6,
#  4.4,
#  3.2,
#  4.7,
#  4.5,
#  4.3,
#  4.6,
#  4.0,
#  4.1,
#  4.7,
#  nan,
#  4.7,
#  4.8,
#  4.7,
#  4.1,
#  3.9,
#  4.1,
#  4.2,
#  4.1,
#  4.5,
#  4.2,
#  4.7,
#  3.8,
#  4.7,
#  4.1,
#  4.7,
#  4.0,
#  4.2,
#  4.5,
#  4.4,
#  3.8,
#  4.2,
#  4.7,
#  4.6,
#  4.2,
#  4.3,
#  4.2,
#  4.0,
#  3.8,
#  4.6,
#  3.9,
#  4.3,
#  4.9,
#  4.4,
#  4.2,
#  4.0,
#  3.9,
#  4.6,
#  4.9,
#  4.3,
#  4.6,
#  4.9,
#  3.9,
#  4.0,
#  4.3,
#  3.9,
#  4.2,
#  4.8,
#  3.6,
#  4.2,
#  4.8,
#  4.8,
#  4.6,
#  4.5,
#  4.3,
#  4.5,
#  4.9,
#  3.9,
#  4.4,
#  4.0,
#  4.3,
#  3.7,
#  4.4,
#  4.3,
#  3.2,
#  4.6,
#  4.6,
#  4.5,
#  3.7,
#  4.6,
#  4.6,
#  4.6,
#  4.0,
#  4.4,
#  4.0,
#  4.7,
#  4.9,
#  4.7,
#  3.9,
#  3.9,
#  4.2,
#  4.6,
#  4.3,
#  4.7,
#  4.7,
#  4.8,
#  4.2,
#  4.3,
#  4.5,
#  4.1,
#  nan,
#  4.2,
#  4.5,
#  4.4,
#  4.0,
#  4.1,
#  4.1,
#  4.4,
#  4.6,
#  4.5,
#  nan,
#  3.9,
# ...

# %%
play.iloc[10838]
# Out:
# App               Parkinson Exercices FR
# Category                         MEDICAL
# Rating                               NaN
# Reviews                                3
# Size                                9.5M
# Installs                          1,000+
# Type                                Free
# Price                                  0
# Content Rating                  Everyone
# Genres                           Medical
# Last Updated            January 20, 2017
# Current Ver                          1.0
# Android Ver                   2.2 and up
# Name: 10838, dtype: object

# %%
play['Rating'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838     True
# 10839    False
# 10840    False
# Name: Rating, Length: 10841, dtype: bool

# %%
play['Rating'].isnull().sum()
# Out:
# 1474

# %%
play[play['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
play[play['Rating'].isnull()].count()
# Out:
# App               1474
# Category          1474
# Rating               0
# Reviews           1474
# Size              1474
# Installs          1474
# Type              1473
# Price             1474
# Content Rating    1474
# Genres            1474
# Last Updated      1474
# Current Ver       1470
# Android Ver       1474
# dtype: int64

# %%
play['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
play['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
play[play['Category'] == '1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
play.drop(play.index[10472])
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
play['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
len(play['App'].unique())
# Out:
# 9660

# %%
play[play['App'] == 'Facebook']
# Out:
#            App Category  Rating   Reviews                Size        Installs  \
# 2544  Facebook   SOCIAL     4.1  78158306  Varies with device  1,000,000,000+
# 3943  Facebook   SOCIAL     4.1  78128208  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres    Last Updated         Current Ver  \
# 2544  Free     0           Teen  Social  August 3, 2018  Varies with device
# 3943  Free     0           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2544  Varies with device
# 3943  Varies with device

# %%
import pandas as pd
import seaborn as sns
planets = sns.load_dataset('planets')
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[tips['total_bill'] < tips['tip']]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips['percentuale'] = tips['tip'] / tips['total_bill'] * 100
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentuale
# 0         16.99  1.01  Female     No   Sun  Dinner     2     5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3    16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2    13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4    14.680765
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.974441
#
# [244 rows x 8 columns]

# %%
tips.min()
# Out:
# total_bill        3.07
# tip                  1
# sex             Female
# smoker              No
# day                Fri
# time            Dinner
# size                 1
# percentuale    3.56381
# dtype: object

# %%
tips.max()
# Out:
# total_bill       50.81
# tip                 10
# sex               Male
# smoker             Yes
# day               Thur
# time             Lunch
# size                 6
# percentuale    71.0345
# dtype: object

# %%
tips[tips['percentuale'] >40]
# Out:
#      total_bill   tip     sex smoker  day    time  size  percentuale
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2    71.034483
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2    41.666667

# %%
tips['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'percentuale'],
#       dtype='object')

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
f1_drivers = pd.read_csv("https://raw.githubusercontent.com/gdv/foundationsCS-2018/master/ex-data/f1-db/drivers.csv",
                        parse_dates=['dob'])

# %%
f1_drivers
# Out:
#      driverId        driverRef  number code  forename     surname        dob  \
# 0           1         hamilton    44.0  HAM     Lewis    Hamilton 1985-07-01
# 1           2         heidfeld     NaN  HEI      Nick    Heidfeld 1977-10-05
# 2           3          rosberg     6.0  ROS      Nico     Rosberg 1985-06-27
# 3           4           alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 4           5       kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
# ..        ...              ...     ...  ...       ...         ...        ...
# 837       838        vandoorne     2.0  VAN   Stoffel   Vandoorne 1992-03-26
# 838       839             ocon    31.0  OCO   Esteban        Ocon 1996-09-17
# 839       840           stroll    18.0  STR     Lance      Stroll 1998-10-29
# 840       841       giovinazzi    36.0  GIO   Antonio  Giovinazzi 1993-12-14
# 841       843  brendon_hartley    39.0  HAR   Brendon     Hartley 1989-10-11
#
# ...

# %%
nuovo = f1_drivers.set_index('driverId')
nuovo
# Out:
#                 driverRef  number code  forename     surname        dob  \
# driverId
# 1                hamilton    44.0  HAM     Lewis    Hamilton 1985-07-01
# 2                heidfeld     NaN  HEI      Nick    Heidfeld 1977-10-05
# 3                 rosberg     6.0  ROS      Nico     Rosberg 1985-06-27
# 4                  alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 5              kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
# ...                   ...     ...  ...       ...         ...        ...
# 838             vandoorne     2.0  VAN   Stoffel   Vandoorne 1992-03-26
# 839                  ocon    31.0  OCO   Esteban        Ocon 1996-09-17
# 840                stroll    18.0  STR     Lance      Stroll 1998-10-29
# 841            giovinazzi    36.0  GIO   Antonio  Giovinazzi 1993-12-14
# 843       brendon_hartley    39.0  HAR   Brendon     Hartley 1989-10-11
#
#             nationality                                              url
# driverId
# ...

# %%
nuovo.iloc[3]
# Out:
# driverRef                                            alonso
# number                                                   14
# code                                                    ALO
# forename                                           Fernando
# surname                                              Alonso
# dob                                     1981-07-29 00:00:00
# nationality                                         Spanish
# url            http://en.wikipedia.org/wiki/Fernando_Alonso
# Name: 4, dtype: object

# %%
nuovo.loc[3]
# Out:
# driverRef                                        rosberg
# number                                                 6
# code                                                 ROS
# forename                                            Nico
# surname                                          Rosberg
# dob                                  1985-06-27 00:00:00
# nationality                                       German
# url            http://en.wikipedia.org/wiki/Nico_Rosberg
# Name: 3, dtype: object

# %%
nuovo.iloc[3:5]
# Out:
#            driverRef  number code  forename     surname        dob  \
# driverId
# 4             alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 5         kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
#
#          nationality                                             url
# driverId
# 4            Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 5            Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
nuovo.loc[3:5]
# Out:
#            driverRef  number code  forename     surname        dob  \
# driverId
# 3            rosberg     6.0  ROS      Nico     Rosberg 1985-06-27
# 4             alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 5         kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
#
#          nationality                                             url
# driverId
# 3             German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 4            Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 5            Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
nuovo.head()
# Out:
#            driverRef  number code  forename     surname        dob  \
# driverId
# 1           hamilton    44.0  HAM     Lewis    Hamilton 1985-07-01
# 2           heidfeld     NaN  HEI      Nick    Heidfeld 1977-10-05
# 3            rosberg     6.0  ROS      Nico     Rosberg 1985-06-27
# 4             alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 5         kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
#
#          nationality                                             url
# driverId
# 1            British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2             German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 3             German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 4            Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 5            Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
nuovo['dob']
# Out:
# driverId
# 1     1985-07-01
# 2     1977-10-05
# 3     1985-06-27
# 4     1981-07-29
# 5     1981-10-19
#          ...
# 838   1992-03-26
# 839   1996-09-17
# 840   1998-10-29
# 841   1993-12-14
# 843   1989-10-11
# Name: dob, Length: 842, dtype: datetime64[ns]

# %%
nuovo.iloc[:10]['dob']
# Out:
# driverId
# 1    1985-07-01
# 2    1977-10-05
# 3    1985-06-27
# 4    1981-07-29
# 5    1981-10-19
# 6    1985-11-01
# 7    1979-02-28
# 8    1979-10-17
# 9    1984-07-12
# 10   1982-03-18
# Name: dob, dtype: datetime64[ns]

# %%
nuovo.iloc[:10]['dob'].dt.year
# Out:
# driverId
# 1     1985
# 2     1977
# 3     1985
# 4     1981
# 5     1981
# 6     1985
# 7     1979
# 8     1979
# 9     1984
# 10    1982
# Name: dob, dtype: int64

# %%
nuovo['anno nascita'] = nuovo['dob'].dt.year
nuovo
# Out:
#                 driverRef  number code  forename     surname        dob  \
# driverId
# 1                hamilton    44.0  HAM     Lewis    Hamilton 1985-07-01
# 2                heidfeld     NaN  HEI      Nick    Heidfeld 1977-10-05
# 3                 rosberg     6.0  ROS      Nico     Rosberg 1985-06-27
# 4                  alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 5              kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
# ...                   ...     ...  ...       ...         ...        ...
# 838             vandoorne     2.0  VAN   Stoffel   Vandoorne 1992-03-26
# 839                  ocon    31.0  OCO   Esteban        Ocon 1996-09-17
# 840                stroll    18.0  STR     Lance      Stroll 1998-10-29
# 841            giovinazzi    36.0  GIO   Antonio  Giovinazzi 1993-12-14
# 843       brendon_hartley    39.0  HAR   Brendon     Hartley 1989-10-11
#
#             nationality                                              url  \
# driverId
# ...

# %%
nuovo.head()
# Out:
#            driverRef  number code  forename     surname        dob  \
# driverId
# 1           hamilton    44.0  HAM     Lewis    Hamilton 1985-07-01
# 2           heidfeld     NaN  HEI      Nick    Heidfeld 1977-10-05
# 3            rosberg     6.0  ROS      Nico     Rosberg 1985-06-27
# 4             alonso    14.0  ALO  Fernando      Alonso 1981-07-29
# 5         kovalainen     NaN  KOV    Heikki  Kovalainen 1981-10-19
#
#          nationality                                             url  \
# driverId
# 1            British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2             German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 3             German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 4            Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 5            Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
#
#           anno nascita
# driverId
# 1                 1985
# 2                 1977
# 3                 1985
# ...

# %%
nuovo.tail()
# Out:
#                 driverRef  number code forename     surname        dob  \
# driverId
# 838             vandoorne     2.0  VAN  Stoffel   Vandoorne 1992-03-26
# 839                  ocon    31.0  OCO  Esteban        Ocon 1996-09-17
# 840                stroll    18.0  STR    Lance      Stroll 1998-10-29
# 841            giovinazzi    36.0  GIO  Antonio  Giovinazzi 1993-12-14
# 843       brendon_hartley    39.0  HAR  Brendon     Hartley 1989-10-11
#
#             nationality                                              url  \
# driverId
# 838             Belgian   http://en.wikipedia.org/wiki/Stoffel_Vandoorne
# 839              French        http://en.wikipedia.org/wiki/Esteban_Ocon
# 840            Canadian        http://en.wikipedia.org/wiki/Lance_Stroll
# 841             Italian  http://en.wikipedia.org/wiki/Antonio_Giovinazzi
# 843       New Zealander     http://en.wikipedia.org/wiki/Brendon_Hartley
#
#           anno nascita
# driverId
# 838               1992
# ...

# %%
nuovo.groupby('anno nascita')

# %%
nuovo.groupby('anno nascita')['url'].count()
# Out:
# anno nascita
# 1896    1
# 1898    3
# 1899    3
# 1900    2
# 1902    2
#        ..
# 1993    2
# 1994    3
# 1996    2
# 1997    1
# 1998    1
# Name: url, Length: 100, dtype: int64

# %%
nuovo.groupby('nationality')['url'].count()
# Out:
# nationality
# American             156
# American-Italian       1
# Argentine             24
# Argentine-Italian      1
# Australian            17
# Austrian              15
# Belgian               23
# Brazilian             31
# British              162
# Canadian              13
# Chilean                1
# Colombian              3
# Czech                  1
# Danish                 5
# Dutch                 17
# East German            3
# Finnish                9
# French                73
# German                49
# Hungarian              1
# Indian                 2
# Indonesian             1
# Irish                  5
# Italian               99
# Japanese              19
# Liechtensteiner        1
# Malaysian              1
# Mexican                6
# Monegasque             3
# New Zealander          9
# Polish                 1
# Portuguese             4
# Rhodesian              4
# Russian                2
# South African         23
# Spanish               15
# ...

# %%
nuovo.groupby(['anno nascita', 'nationality'])['url'].count()
# Out:
# anno nascita  nationality
# 1896          French         1
# 1898          Belgian        1
#               Italian        2
# 1899          German         1
#               Italian        1
#                             ..
# 1994          Russian        1
#               Spanish        1
# 1996          French         2
# 1997          Dutch          1
# 1998          Canadian       1
# Name: url, Length: 520, dtype: int64

# %%
tips.describe()
# Out:
#        total_bill         tip        size  percentuale
# count  244.000000  244.000000  244.000000   244.000000
# mean    19.785943    2.998279    2.569672    16.080258
# std      8.902412    1.383638    0.951100     6.107220
# min      3.070000    1.000000    1.000000     3.563814
# 25%     13.347500    2.000000    2.000000    12.912736
# 50%     17.795000    2.900000    2.000000    15.476977
# 75%     24.127500    3.562500    3.000000    19.147549
# max     50.810000   10.000000    6.000000    71.034483

# %%
movies = pd.read_csv("https://github.com/gdv/scuole-lincei/raw/master/data/rotten_tomatoes_movies.csv.gz")
movies.head()
# Out:
#                      rotten_tomatoes_link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %%
reviews = pd.read_csv("https://github.com/gdv/scuole-lincei/raw/master/data/rotten_tomatoes_reviews.csv.gz",
                     parse_dates = ['review_date'])

# %%
reviews.head()
# Out:
#   rotten_tomatoes_link review_date          critic_publication critic_icon  \
# 0           /m/0814255  2015-01-09             Cinemaphile.org      Rotten
# 1           /m/0814255  2012-07-31                 7M Pictures       Fresh
# 2           /m/0814255  2011-11-05  Star-Democrat (Easton, MD)      Rotten
# 3           /m/0814255  2011-04-25              ComingSoon.net      Rotten
# 4           /m/0814255  2011-04-04                  Movies.com      Rotten
#
#   critic_top  critic_score                                     review_content
# 0        NaN           NaN  The plot uses the presence of the Greek gods a...
# 1        NaN           NaN  It provides a great adventure movie for the fa...
# 2        NaN           NaN  The premise of Percy Jackson & the Olympians: ...
# 3        NaN           NaN  Percy Jackson is simply uninspired in every si...
# 4        NaN           NaN    It kind of just builds up to a lot of Not Much.

# %%
reviews['review_date']
# Out:
# 0        2015-01-09
# 1        2012-07-31
# 2        2011-11-05
# 3        2011-04-25
# 4        2011-04-04
#             ...
# 930937   2007-03-07
# 930938   2005-11-02
# 930939   2005-11-01
# 930940   2005-08-14
# 930941   2005-06-25
# Name: review_date, Length: 930942, dtype: datetime64[ns]

# %%
movies = movies.set_index('rotten_tomatoes_link')

# %%
movies.head()
# Out:
#                                                                               movie_title  \
# rotten_tomatoes_link
# /m/0814255                              Percy Jackson & the Olympians: The Lightning T...
# /m/0878835                                                                    Please Give
# /m/10                                                                                  10
# /m/1000013-12_angry_men                                   12 Angry Men (Twelve Angry Men)
# /m/1000079-20000_leagues_under_the_sea                       20,000 Leagues Under The Sea
#
#                                                                                movie_info  \
# rotten_tomatoes_link
# /m/0814255                              A teenager discovers he's the descendant of a ...
# /m/0878835                              Kate has a lot on her mind. There's the ethics...
# /m/10                                   Blake Edwards' 10 stars Dudley Moore as George...
# ...

# %%
movies.columns
# Out:
# Index(['movie_title', 'movie_info', 'critics_consensus', 'poster_image_url',
#        'rating', 'genre', 'directors', 'writers', 'cast', 'in_theaters_date',
#        'on_streaming_date', 'runtime_in_minutes', 'studio_name',
#        'tomatometer_status', 'tomatometer_rating', 'tomatometer_count',
#        'audience_status', 'audience_rating', 'audience_count',
#        'audience_top_critics_count', 'audience_fresh_critics_count',
#        'audience_rotten_critics_count'],
#       dtype='object')

# %%
reviews.columns
# Out:
# Index(['rotten_tomatoes_link', 'review_date', 'critic_publication',
#        'critic_icon', 'critic_top', 'critic_score', 'review_content'],
#       dtype='object')

# %%
tabella = pd.merge(movies, reviews, left_index = True, right_on = 'rotten_tomatoes_link')
tabella
# Out:
#                                               movie_title  \
# 0       Percy Jackson & the Olympians: The Lightning T...
# 1       Percy Jackson & the Olympians: The Lightning T...
# 2       Percy Jackson & the Olympians: The Lightning T...
# 3       Percy Jackson & the Olympians: The Lightning T...
# 4       Percy Jackson & the Olympians: The Lightning T...
# ...                                                   ...
# 930937                                          Zulu Dawn
# 930938                                          Zulu Dawn
# 930939                                          Zulu Dawn
# 930940                                          Zulu Dawn
# 930941                                          Zulu Dawn
#
#                                                movie_info  \
# 0       A teenager discovers he's the descendant of a ...
# 1       A teenager discovers he's the descendant of a ...
# 2       A teenager discovers he's the descendant of a ...
# ...

# %%
vecchi = tabella.groupby('rotten_tomatoes_link', as_index = False)['review_date'].min()
vecchi
# Out:
#                          rotten_tomatoes_link review_date
# 0                                  /m/0814255  2010-02-06
# 1                                  /m/0878835  2010-01-25
# 2                                       /m/10  2000-01-01
# 3                     /m/1000013-12_angry_men  2000-01-01
# 4      /m/1000079-20000_leagues_under_the_sea  2000-01-01
# ...                                       ...         ...
# 16589                            /m/zoot_suit  2000-01-01
# 16590                             /m/zootopia  2016-02-12
# 16591                      /m/zorba_the_greek  2003-09-05
# 16592                                 /m/zulu  1964-06-17
# 16593                            /m/zulu_dawn  2005-06-25
#
# [16594 rows x 2 columns]

# %%
recenti = tabella.groupby('rotten_tomatoes_link', as_index = False)['review_date'].max()
recenti
# Out:
#                          rotten_tomatoes_link review_date
# 0                                  /m/0814255  2015-01-09
# 1                                  /m/0878835  2019-07-23
# 2                                       /m/10  2011-02-11
# 3                     /m/1000013-12_angry_men  2019-10-14
# 4      /m/1000079-20000_leagues_under_the_sea  2012-05-31
# ...                                       ...         ...
# 16589                            /m/zoot_suit  2019-05-01
# 16590                             /m/zootopia  2019-10-22
# 16591                      /m/zorba_the_greek  2019-07-16
# 16592                                 /m/zulu  2017-07-10
# 16593                            /m/zulu_dawn  2011-02-28
#
# [16594 rows x 2 columns]

# %%
temporanea = pd.merge(movies, vecchi, left_index = True, right_on = 'rotten_tomatoes_link' )[['movie_title', 
                                                                                 'rotten_tomatoes_link',
                                                                                'review_date']]
temporanea
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16589                                          Zoot Suit
# 16590                                           Zootopia
# 16591                                    Zorba the Greek
# 16592                                               Zulu
# 16593                                          Zulu Dawn
#
#                          rotten_tomatoes_link review_date
# 0                                  /m/0814255  2010-02-06
# 1                                  /m/0878835  2010-01-25
# 2                                       /m/10  2000-01-01
# ...

# %%
finale = pd.merge(temporanea, recenti, on = 'rotten_tomatoes_link')
finale
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16589                                          Zoot Suit
# 16590                                           Zootopia
# 16591                                    Zorba the Greek
# 16592                                               Zulu
# 16593                                          Zulu Dawn
#
#                          rotten_tomatoes_link review_date_x review_date_y
# 0                                  /m/0814255    2010-02-06    2015-01-09
# 1                                  /m/0878835    2010-01-25    2019-07-23
# ...

# %%
finale.columns = ['movie_title', 'rotten_tomatoes_link', 'prima', 'ultima']

# %%
finale
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16589                                          Zoot Suit
# 16590                                           Zootopia
# 16591                                    Zorba the Greek
# 16592                                               Zulu
# 16593                                          Zulu Dawn
#
#                          rotten_tomatoes_link      prima     ultima
# 0                                  /m/0814255 2010-02-06 2015-01-09
# 1                                  /m/0878835 2010-01-25 2019-07-23
# 2                                       /m/10 2000-01-01 2011-02-11
# ...

# %%
finale['intervallo'] = finale['ultima'] - finale['prima']

# %%
finale
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16589                                          Zoot Suit
# 16590                                           Zootopia
# 16591                                    Zorba the Greek
# 16592                                               Zulu
# 16593                                          Zulu Dawn
#
#                          rotten_tomatoes_link      prima     ultima intervallo
# 0                                  /m/0814255 2010-02-06 2015-01-09  1798 days
# 1                                  /m/0878835 2010-01-25 2019-07-23  3466 days
# ...

# %% [markdown]
# ## Concatenazione

# %%
giorno1 = pd.read_csv("https://github.com/pcm-dpc/COVID-19/raw/master/dati-province/dpc-covid19-ita-province-20200322.csv")
giorno1
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 0    2020-03-22 17:00:00   ITA              13               Abruzzo
# 1    2020-03-22 17:00:00   ITA              13               Abruzzo
# 2    2020-03-22 17:00:00   ITA              13               Abruzzo
# 3    2020-03-22 17:00:00   ITA              13               Abruzzo
# 4    2020-03-22 17:00:00   ITA              13               Abruzzo
# ..                   ...   ...             ...                   ...
# 123  2020-03-22 17:00:00   ITA               5                Veneto
# 124  2020-03-22 17:00:00   ITA               5                Veneto
# 125  2020-03-22 17:00:00   ITA               5                Veneto
# 126  2020-03-22 17:00:00   ITA               5                Veneto
# 127  2020-03-22 17:00:00   ITA               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# ...

# %%
giorno2 = pd.read_csv("https://github.com/pcm-dpc/COVID-19/raw/master/dati-province/dpc-covid19-ita-province-20200321.csv")
giorno2
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 0    2020-03-21 17:00:00   ITA              13               Abruzzo
# 1    2020-03-21 17:00:00   ITA              13               Abruzzo
# 2    2020-03-21 17:00:00   ITA              13               Abruzzo
# 3    2020-03-21 17:00:00   ITA              13               Abruzzo
# 4    2020-03-21 17:00:00   ITA              13               Abruzzo
# ..                   ...   ...             ...                   ...
# 123  2020-03-21 17:00:00   ITA               5                Veneto
# 124  2020-03-21 17:00:00   ITA               5                Veneto
# 125  2020-03-21 17:00:00   ITA               5                Veneto
# 126  2020-03-21 17:00:00   ITA               5                Veneto
# 127  2020-03-21 17:00:00   ITA               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# ...

# %%
totale = pd.concat([giorno1, giorno2])
totale
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 0    2020-03-22 17:00:00   ITA              13               Abruzzo
# 1    2020-03-22 17:00:00   ITA              13               Abruzzo
# 2    2020-03-22 17:00:00   ITA              13               Abruzzo
# 3    2020-03-22 17:00:00   ITA              13               Abruzzo
# 4    2020-03-22 17:00:00   ITA              13               Abruzzo
# ..                   ...   ...             ...                   ...
# 123  2020-03-21 17:00:00   ITA               5                Veneto
# 124  2020-03-21 17:00:00   ITA               5                Veneto
# 125  2020-03-21 17:00:00   ITA               5                Veneto
# 126  2020-03-21 17:00:00   ITA               5                Veneto
# 127  2020-03-21 17:00:00   ITA               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# ...

# %%
sns.catplot(x="day", y="total_bill", data=tips);

# %%
sns.catplot(x="day", y="tip", data=tips);

# %%
sns.catplot(x="day", y="total_bill", kind="swarm", data=tips);

# %%
sns.catplot(x="day", y="total_bill", kind="violin", data=tips);

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="bar", data=tips);

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
import numpy as np
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,
           lowess=True);

# %%
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
           aspect=.5);

# %%
pd.read_excel
pd.read_json

# %%
lista1 = [ 9, 32, 99]
lista1
# Out:
# [9, 32, 99]

# %%
lista2 = lista1
lista2
# Out:
# [9, 32, 99]

# %%
lista2[1] = 0
lista2
# Out:
# [9, 0, 99]

# %%
lista1
# Out:
# [9, 0, 99]
