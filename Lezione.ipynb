# %%
import pandas as pd

# %%
istat = pd.read_csv('data/istat-giovani.csv')
istat
# Out:
#       ITTER107   Territorio TIPO_DATO_FOL  \
# 0           IT       Italia        POP_15
# 1           IT       Italia        POP_15
# 2           IT       Italia        POP_15
# 3           IT       Italia        POP_15
# 4           IT       Italia        POP_15
# 5           IT       Italia        POP_15
# 6           IT       Italia        POP_15
# 7           IT       Italia        POP_15
# 8           IT       Italia        POP_15
# 9           IT       Italia        POP_15
# 10          IT       Italia        POP_15
# 11          IT       Italia        POP_15
# 12          IT       Italia        POP_15
# 13          IT       Italia        POP_15
# 14          IT       Italia        POP_15
# 15          IT       Italia        POP_15
# 16          IT       Italia        POP_15
# 17          IT       Italia        POP_15
# 18          IT       Italia        POP_15
# 19          IT       Italia        POP_15
# 20          IT       Italia        POP_15
# ...

# %%
testo = pd.read_csv('http://www.gutenberg.org/cache/epub/18457/pg18457.txt', delimiter = "\n", skiprows = 30)
testo
# Out:
#                        Sei personaggi in cerca d'autore
# 0                                   di Luigi Pirandello
# 1                   I PERSONAGGI DELLA COMMEDIA DA FARE
# 2                                              Il padre
# 3                                              La madre
# 4                                         La figliastra
# 5                                             Il figlio
# 6                                         Il giovinetto
# 7                                            La bambina
# 8                       (questi ultimi due non parlano)
# 9                            (Poi, evocata) Madama Pace
# 10                           GLI ATTORI DELLA COMPAGNIA
# 11                              Il direttore-capocomico
# 12                                     La prima attrice
# 13                                      Il primo attore
# 14                                     La seconda donna
# 15                                    L'attrice giovane
# ...
